# %% [markdown]
# # Loading in CitySpaces data from local

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.12/site-packages (0.21.0)

# %%
from dotenv import load_dotenv
import os
import shutil

load_dotenv()
source_dir = os.getenv("SRC_DATA_PATH") # change to your own source folder that is the your unzipped cityScapes folder
print(source_dir)
dest_dir = os.getcwd()

os.makedirs(os.path.join(dest_dir, "images"), exist_ok=True)
# creating two subdirs for train and test data
os.makedirs(os.path.join(dest_dir, "images", "train"), exist_ok=True)
os.makedirs(os.path.join(dest_dir, "images", "test"), exist_ok=True)

# CityScapes dataset is in the format:
# train
    # img
    # label
# val
    # img
    # label
def copy_folder(folder, target):
    folder = os.path.join(source_dir, folder)

    for subfolder in os.listdir(folder):
        if subfolder == ".DS_Store":
            continue
        for file in os.listdir(os.path.join(folder, subfolder)):
            try:
                    
                src = os.path.join(folder, subfolder, file)
                os.makedirs(os.path.join(dest_dir, "images", target, subfolder), exist_ok=True) # creating label, images subfolders
                dest = os.path.join(dest_dir, "images", target, subfolder, file)

                if os.path.exists(dest): # Added to avoid copying the same file again
                    print(f"File {dest} already exists. Skipping.")
                    continue

                if os.path.exists(src):
                    print(f"Copying {src} to {dest}")
                    shutil.copy2(src, dest)
            
            except Exception as e:
                print("Error: {e}")

copy_folder("train", "train")
copy_folder("val", "test")
print("Data copied successfully!")
# Out:
# /Users/adarshdanda/Desktop/CityScapesData
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1760.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2269.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1006.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1012.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1774.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2255.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1984.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2533.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2527.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1748.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1990.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2241.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train507.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train261.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train275.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train513.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1947.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2296.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train249.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2282.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1953.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1204.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1562.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1576.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2719.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1210.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2731.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1238.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train922.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2057.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train936.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2043.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2725.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2916.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train10.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train705.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train711.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2902.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train739.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2094.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1589.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train38.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2080.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1370.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2679.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1416.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1402.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1364.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2645.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train856.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2123.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train842.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2137.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1358.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2651.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2889.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2862.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train117.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train671.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train665.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2876.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train103.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2686.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train895.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train881.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train659.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2692.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1614.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1172.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1166.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2309.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1600.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2321.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1628.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2447.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2453.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2335.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train498.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train473.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train315.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train301.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train467.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1833.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2484.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train329.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1199.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2490.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1827.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2491.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1198.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1826.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1832.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train328.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2485.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train300.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train466.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train472.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train314.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2452.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train499.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2334.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1629.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2320.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2446.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1167.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1601.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2308.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1615.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1173.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train658.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train880.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2693.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2687.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train894.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train664.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train102.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2877.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train116.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2863.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train670.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2136.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train843.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2888.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2650.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1359.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2644.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2122.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train857.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1403.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1365.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2678.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1371.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1417.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2081.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train39.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1588.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2095.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train738.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train710.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2903.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2917.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train11.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train704.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2042.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train937.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2724.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1239.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2730.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2056.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train923.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1577.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1211.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2718.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1205.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1563.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train248.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1952.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2283.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2297.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1946.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train274.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train512.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train506.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train260.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2526.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2240.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1991.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1749.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1985.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2254.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2532.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1013.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1775.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2268.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1761.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1007.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1777.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1011.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2518.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1005.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1763.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1993.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2242.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2524.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train289.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1039.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2530.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2256.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1987.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train510.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train276.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train262.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train504.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1978.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2281.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1950.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1788.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1944.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2295.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train538.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1213.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1575.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train909.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2068.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1561.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1207.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2726.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2040.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train935.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1549.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2054.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train921.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2732.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2901.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train712.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train706.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train13.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2915.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2083.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2097.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2929.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1367.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1401.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2108.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train869.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1415.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1373.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2652.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train699.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2134.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train841.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1429.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2120.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train855.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2646.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train100.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2875.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train666.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train672.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train114.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2861.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2849.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2691.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1398.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train882.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train896.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train128.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2685.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1603.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1165.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2478.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1171.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1617.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2336.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2450.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1159.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2444.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2322.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1818.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train464.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train302.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train316.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train470.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train458.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1824.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2493.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2487.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1830.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2486.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1831.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1825.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train459.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2492.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train317.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train471.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train465.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1819.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train303.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2445.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2323.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2337.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1158.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2451.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1170.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2479.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1616.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1602.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1164.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train897.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2684.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train129.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1399.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2690.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2848.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train883.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train673.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2860.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train115.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2874.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train101.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train667.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train854.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2121.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1428.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2647.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2653.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train840.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2135.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train698.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1414.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train868.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1372.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1366.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2109.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1400.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2096.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2928.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2082.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train707.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train12.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2914.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2900.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train713.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train920.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2055.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2733.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2727.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1548.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train934.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2041.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1560.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2069.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1206.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1212.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train908.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1574.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train539.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2294.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1945.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1789.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1951.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2280.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train263.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1979.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train505.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train511.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train277.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2531.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1038.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1986.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2257.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2243.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1992.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train288.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2525.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1004.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1762.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1776.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2519.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1010.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2521.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1028.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1996.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2247.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2253.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1982.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2535.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train298.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1014.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1772.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1766.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2509.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1000.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2284.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train529.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1955.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1941.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1799.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2290.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train273.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1969.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train515.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train501.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train267.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2045.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train930.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2723.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2737.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1558.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2051.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train924.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1570.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2079.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1216.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1202.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train918.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1564.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2086.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2938.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2092.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train717.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2904.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2910.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train16.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train703.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2131.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train844.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train1438.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2657.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train2643.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/train/label/train688.png already exists. Skipping.
# ...
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val149.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val405.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val363.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val79.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val377.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val411.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val439.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val45.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val51.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val86.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val92.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val388.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val217.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val203.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val202.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val216.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val389.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val93.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val87.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val50.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val438.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val44.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val376.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val410.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val404.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val78.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val362.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val148.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val174.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val160.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val107.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val113.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val339.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val23.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val37.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val463.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val305.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val311.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val477.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val488.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val259.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val271.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val265.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val4.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val5.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val264.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val270.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val258.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val489.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val310.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val476.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val462.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val304.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val36.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val22.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val338.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val112.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val106.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val138.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val110.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val104.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val448.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val34.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val20.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val474.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val312.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val306.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val460.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val500.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val266.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val272.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val299.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val7.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val6.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val298.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val273.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val267.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val307.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val461.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val475.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val313.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val21.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val449.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val35.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val105.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val111.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val139.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val115.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val101.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val129.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val317.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val471.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val465.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val303.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val19.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val31.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val459.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val25.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val263.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val277.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val2.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val288.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val289.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val3.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val276.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val262.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val458.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val24.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val30.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val464.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val18.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val302.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val316.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val470.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val128.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val100.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val114.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val102.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val116.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val300.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val466.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val472.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val314.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val26.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val328.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val32.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val499.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val274.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val260.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val248.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val1.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val249.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val261.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val275.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val498.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val33.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val329.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val27.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val473.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val315.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val301.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val467.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val117.png already exists. Skipping.
# File /Users/adarshdanda/MLResumeProj/SemanticSegmentation/images/test/img/val103.png already exists. Skipping.
# Data copied successfully!

# %% [markdown]
# ## Creating Custom Data Loader Pytorch

# %%
import matplotlib.pyplot as plt

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os

class CityscapesDataLoader(Dataset):
    def __init__(self, image_paths, label_paths, transform=None):
        self.image_paths = image_paths
        self.label_paths = label_paths
        self.transform = transform
        self.images = sorted(os.listdir(image_paths))
        self.masks = sorted(os.listdir(label_paths))

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img = self.images[idx]
        label = self.label[idx]
        img = Image.open(img).convert("RGB")
        label = Image.open(label)

        if self.transform:
            img = self.transform(img)
            label = self.transform(label)

        return img, label

# %%
from torchvision import transforms

def transform_data(img, label):
    transform_img = transforms.Compose([
        transforms.Resize((256, 512)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) # Image Net stats
    ])

    transform_label = transforms.Compose([
        transforms.Resize((256, 512)),
        transforms.ToTensor()
    ])

    return transform_img(img), transform_label(label)

# %%
from torch.utils.data import DataLoader
train_path = './images/train'
test_path = './images/test'

train_data = CityscapesDataLoader(os.path.join(train_path, 'img'), os.path.join(train_path, 'label'), transform=transform_data)
test_data = CityscapesDataLoader(os.path.join(test_path, 'img'), os.path.join(test_path, 'label'), transform=transform_data)

train_loader = DataLoader(train_data, batch_size=4, shuffle=True)
test_loader = DataLoader(test_data, batch_size=4, shuffle=False)
